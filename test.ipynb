# %%
from sklearn.datasets import load_boston
from utils import part
import pandas as pd

# %%
data = load_boston()
x = pd.DataFrame(data.data,columns=data.feature_names)
y = pd.DataFrame(data.target,columns=['price'])
df = x.join(y)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
part1 = part.PartBulider(df=df,x_col=x.columns,y_col=y.columns)

# %%
part1.train()
# Out:
#   4%|▎         | 11/300 [00:00<00:05, 48.86it/s]epoch:0 train_loss:0.0356 valid_loss:0.0177
#  20%|██        | 61/300 [00:00<00:03, 66.91it/s]epoch:50 train_loss:0.0027 valid_loss:0.0093
#  37%|███▋      | 112/300 [00:01<00:02, 64.15it/s]epoch:100 train_loss:0.0015 valid_loss:0.0106
#  54%|█████▎    | 161/300 [00:02<00:02, 64.46it/s]epoch:150 train_loss:0.0011 valid_loss:0.0102
#  68%|██████▊   | 205/300 [00:03<00:01, 50.04it/s]epoch:200 train_loss:0.0016 valid_loss:0.0105
#  87%|████████▋ | 261/300 [00:04<00:00, 55.56it/s]epoch:250 train_loss:0.0008 valid_loss:0.0112
# 100%|██████████| 300/300 [00:05<00:00, 57.51it/s]
# Sequential(
#   (0): Linear(in_features=13, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
part1.test()
# Out:
#             R2      MSE     MAPE
# price  0.82252  13.3016  8.36797
# AVG    0.82252  13.3016  8.36797
