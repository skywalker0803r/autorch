# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/autorch/blob/main/autorch_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install autorch

# %%
from autorch.function import sp2wt
from autorch.utils import part
import torch
from torch import nn 
from tqdm import tqdm_notebook as tqdm

# %%
import pandas as pd
import numpy as np
import joblib
c = joblib.load('/content/drive/MyDrive/台塑輕油案子/data/phase2/dataset/col_names.pkl')
df = pd.read_csv('/content/drive/MyDrive/台塑輕油案子/data/phase2/dataset/train.csv',index_col=0)

# %%
# test sp2wt
x = df[c["xna"]].values
s = df[c["shc"]].values
wt = df[c["xhc"]].values
wt_p = sp2wt(x,s)
np.allclose(wt,wt_p)
# Out:
# True

# %%
# define columns,normalize_idx
x_col = c['case'] + c['xna']
y_col = c['sle'] + c['shc'] + c['she']
normalize_idx = [[y_col.index(c['sle'][i]),y_col.index(c['shc'][i]),y_col.index(c['she'][i])]for i in range(len(c['xna']))]
normalize_idx
# Out:
# [[0, 54, 108],
#  [1, 55, 109],
#  [2, 56, 110],
#  [3, 57, 111],
#  [4, 58, 112],
#  [5, 59, 113],
#  [6, 60, 114],
#  [7, 61, 115],
#  [8, 62, 116],
#  [9, 63, 117],
#  [10, 64, 118],
#  [11, 65, 119],
#  [12, 66, 120],
#  [13, 67, 121],
#  [14, 68, 122],
#  [15, 69, 123],
#  [16, 70, 124],
#  [17, 71, 125],
#  [18, 72, 126],
#  [19, 73, 127],
#  [20, 74, 128],
#  [21, 75, 129],
#  [22, 76, 130],
#  [23, 77, 131],
#  [24, 78, 132],
#  [25, 79, 133],
#  [26, 80, 134],
#  [27, 81, 135],
#  [28, 82, 136],
#  [29, 83, 137],
#  [30, 84, 138],
#  [31, 85, 139],
#  [32, 86, 140],
#  [33, 87, 141],
#  [34, 88, 142],
#  [35, 89, 143],
#  [36, 90, 144],
#  [37, 91, 145],
#  [38, 92, 146],
#  [39, 93, 147],
#  [40, 94, 148],
#  [41, 95, 149],
#  [42, 96, 150],
#  [43, 97, 151],
#  [44, 98, 152],
#  [45, 99, 153],
#  [46, 100, 154],
#  [47, 101, 155],
#  [48, 102, 156],
#  [49, 103, 157],
#  [50, 104, 158],
#  [51, 105, 159],
#  [52, 106, 160],
#  [53, 107, 161]]

# %%
import numpy as np
for i in range(54):
  assert np.allclose(df[y_col].iloc[:,normalize_idx[i]].sum(axis=1).mean(),1.0)

# %%
part1 = part.PartBulider(df,x_col,y_col,normalize_idx_list=normalize_idx)
part1.train()
# Out:
#   0%|          | 1/300 [00:00<03:49,  1.30it/s]
# epoch:0 train_loss:0.0128 valid_loss:0.0037
#  17%|█▋        | 51/300 [00:53<04:24,  1.06s/it]
# epoch:50 train_loss:0.0003 valid_loss:0.0003
#  34%|███▎      | 101/300 [01:47<03:38,  1.10s/it]
# epoch:100 train_loss:0.0002 valid_loss:0.0003
#  50%|█████     | 151/300 [02:44<02:53,  1.17s/it]
# epoch:150 train_loss:0.0001 valid_loss:0.0002
#  67%|██████▋   | 201/300 [03:46<02:09,  1.31s/it]
# epoch:200 train_loss:0.0001 valid_loss:0.0002
#  84%|████████▎ | 251/300 [04:56<01:11,  1.45s/it]
# epoch:250 train_loss:0.0001 valid_loss:0.0001
# 100%|██████████| 300/300 [06:12<00:00,  1.24s/it]
# Sequential(
#   (0): Linear(in_features=58, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=162, bias=True)
#   (5): Sigmoid()
# )

# %%
part1.test()
# Out:
#                                                           R2  ...        MAPE
# Individual Component to Light End Split Factor_...         0  ...  0.00921086
# Individual Component to Light End Split Factor_...         0  ...  0.00930761
# Individual Component to Light End Split Factor_...         0  ...  0.00927526
# Individual Component to Light End Split Factor_...   0.99137  ...   0.0241133
# Individual Component to Light End Split Factor_...   0.99258  ...    0.050942
# ...                                                      ...  ...         ...
# Individual Component to Heavy End Split Factor_...  0.985627  ...    0.681945
# Individual Component to Heavy End Split Factor_...  0.994405  ...         inf
# Individual Component to Heavy End Split Factor_...  0.988504  ...         inf
# Individual Component to Heavy End Split Factor_...         0  ...  0.00940465
# AVG                                                 0.842512  ...         inf
#
# [163 rows x 3 columns]

# %%
# get wt% predict 
x_test = part1.data["X_test"]
s_real = part1.data["Y_test"]
s_pred = part1.predict(x_test)
idx = x_test.index

wt_real = df.loc[idx,c["xle"]+c["xhc"]+c["xhe"]]

xna = x_test[c["xna"]].values
sle = s_pred[c['sle']].values
shc = s_pred[c["shc"]].values
she = s_pred[c["she"]].values

wt_pred = np.hstack((sp2wt(xna,sle),sp2wt(xna,shc),sp2wt(xna,she)))
wt_pred = pd.DataFrame(wt_pred,columns=wt_real.columns)

# %%
pd.options.display.max_rows = 999
result = part1.show_metrics(wt_real,wt_pred)
result
# Out:
#                                                           R2  ...      MAPE
# Light End Product Properties_Oxygen_wt%                    1  ...       NaN
# Light End Product Properties_Methane_wt%                   1  ...       NaN
# Light End Product Properties_Ethane_wt%                    1  ...       NaN
# Light End Product Properties_Propane_wt%            0.996924  ...       NaN
# Light End Product Properties_n-Butane_wt%           0.998186  ...       NaN
# Light End Product Properties_i-Pentane_wt%            0.9977  ...   1.12038
# Light End Product Properties_n-Pentane_wt%          0.997714  ...   1.11728
# Light End Product Properties_tr2-Pentene_wt%        0.998666  ...       NaN
# Light End Product Properties_Cyclopentane_wt%       0.999184  ...       NaN
# Light End Product Properties_3-Methylpentane_wt%    0.998757  ...  0.979775
# Light End Product Properties_tr2-Hexene_wt%         0.999308  ...       NaN
# Light End Product Properties_n-Hexane_wt%            0.99848  ...   0.87659
# Light End Product Properties_Methylcyclopentane...  0.994251  ...  0.566713
# Light End Product Properties_2,2-Dimethylpentan...   0.99042  ...   1.76247
# Light End Product Properties_Benzene_wt%            0.998569  ...       NaN
# Light End Product Properties_Cyclohexane_wt%         0.99513  ...   2.61004
# Light End Product Properties_2,2,3-Trimethylbut...  0.994984  ...   2.73836
# Light End Product Properties_4-Methyl-1-hexene_wt%  0.995879  ...   6.05863
# Light End Product Properties_2-Methylhexane_wt%     0.995102  ...   8.65146
# Light End Product Properties_t-1,3-Dimethylcycl...  0.995529  ...   17.0874
# Light End Product Properties_n-Heptane_wt%          0.987453  ...   13.8528
# Light End Product Properties_H2O_wt%                       1  ...       NaN
# Light End Product Properties_Methylcyclohexane_wt%   0.98784  ...   21.1252
# Light End Product Properties_Ethylcyclopentane_wt%  0.983636  ...   26.4978
# Light End Product Properties_2,3-Dimethyl-1-hex...   0.95341  ...   47.2105
# Light End Product Properties_Toluene_wt%            0.964917  ...   30.5142
# Light End Product Properties_2-Methylheptane_wt%    0.935136  ...   63.2626
# Light End Product Properties_n-Octane_wt%           0.898922  ...   121.163
# Light End Product Properties_Ethylcyclohexane_wt%   0.963626  ...   179.323
# Light End Product Properties_EthylBenzene_wt%       0.903747  ...   122.444
# Light End Product Properties_P-Xylene_wt%           0.896429  ...   79.8299
# Light End Product Properties_M-Xylene_wt%           0.899757  ...   93.4952
# Light End Product Properties_O-Xylene_wt%           0.902795  ...   73.0834
# Light End Product Properties_2-Methyloctane_wt%      0.84133  ...   117.987
# Light End Product Properties_1-Nonene_wt%           0.842493  ...   112.124
# Light End Product Properties_n-Nonane_wt%           0.830799  ...   123.945
# Light End Product Properties_i-Propylbenzene_wt%     0.88566  ...   64.5008
# Light End Product Properties_1-trans-3,5-Trimet...  0.865151  ...   84.6824
# Light End Product Properties_n-Propylcyclohexan...  0.873308  ...   69.3468
# Light End Product Properties_n-Propylbenzene_wt%    0.905523  ...   89.4861
# Light End Product Properties_1,3,5-Trimethylben...   0.91547  ...   154.153
# Light End Product Properties_1-Methyl-2-ethylbe...  0.886776  ...   73.2351
# Light End Product Properties_1,2,3-Trimethylben...  0.943805  ...   1021.16
# Light End Product Properties_2,4-Dimethyloctane...  0.817915  ...    156.96
# Light End Product Properties_2,2,3,3-Tetramethy...  0.838442  ...   103.843
# Light End Product Properties_3-Methylnonane_wt%     0.816468  ...   141.139
# Light End Product Properties_tert-Butylcyclohex...   0.82784  ...   86.7276
# Light End Product Properties_n-Decane_wt%          -0.920534  ...       NaN
# Light End Product Properties_1,2-Diethylbenzene...  0.879527  ...       NaN
# Light End Product Properties_n-Undecane_wt%        -0.745435  ...       NaN
# Light End Product Properties_n-Pentylbenzene_wt%   -0.186112  ...       100
# Light End Product Properties_n-Dodecane_wt%        -0.481504  ...       NaN
# Light End Product Properties_n-Hexylbenzene_wt%    -0.622185  ...       NaN
# Light End Product Properties_n-Tridecane_wt%               1  ...       NaN
# Heart Cut Product Properties_Oxygen_wt%                    1  ...       NaN
# Heart Cut Product Properties_Methane_wt%                   1  ...       NaN
# Heart Cut Product Properties_Ethane_wt%                    1  ...       NaN
# Heart Cut Product Properties_Propane_wt%            0.998368  ...       NaN
# Heart Cut Product Properties_n-Butane_wt%            0.99865  ...       NaN
# Heart Cut Product Properties_i-Pentane_wt%          0.998893  ...   2.03656
# Heart Cut Product Properties_n-Pentane_wt%           0.99886  ...   2.04296
# Heart Cut Product Properties_tr2-Pentene_wt%        0.998594  ...       NaN
# Heart Cut Product Properties_Cyclopentane_wt%       0.998363  ...       NaN
# Heart Cut Product Properties_3-Methylpentane_wt%    0.997704  ...   2.27479
# Heart Cut Product Properties_tr2-Hexene_wt%          0.99832  ...       NaN
# Heart Cut Product Properties_n-Hexane_wt%           0.997749  ...   2.06407
# Heart Cut Product Properties_Methylcyclopentane...  0.998175  ...   1.16309
# Heart Cut Product Properties_2,2-Dimethylpentan...  0.999337  ...  0.690995
# Heart Cut Product Properties_Benzene_wt%            0.999453  ...       NaN
# Heart Cut Product Properties_Cyclohexane_wt%        0.999461  ...  0.752125
# Heart Cut Product Properties_2,2,3-Trimethylbut...  0.999578  ...  0.478604
# Heart Cut Product Properties_4-Methyl-1-hexene_wt%  0.999697  ...  0.306488
# Heart Cut Product Properties_2-Methylhexane_wt%      0.99976  ...  0.229758
# Heart Cut Product Properties_t-1,3-Dimethylcycl...  0.999945  ...  0.187992
# Heart Cut Product Properties_n-Heptane_wt%          0.999878  ...  0.154278
# Heart Cut Product Properties_H2O_wt%                       1  ...       NaN
# Heart Cut Product Properties_Methylcyclohexane_wt%  0.999959  ...   0.15301
# Heart Cut Product Properties_Ethylcyclopentane_wt%  0.999959  ...  0.152665
# Heart Cut Product Properties_2,3-Dimethyl-1-hex...  0.999908  ...   0.15598
# Heart Cut Product Properties_Toluene_wt%            0.999922  ...  0.153451
# Heart Cut Product Properties_2-Methylheptane_wt%    0.999857  ...   0.17025
# Heart Cut Product Properties_n-Octane_wt%           0.999678  ...  0.229719
# Heart Cut Product Properties_Ethylcyclohexane_wt%   0.999462  ...  0.291618
# Heart Cut Product Properties_EthylBenzene_wt%       0.999908  ...  0.318957
# Heart Cut Product Properties_P-Xylene_wt%           0.999909  ...  0.380717
# Heart Cut Product Properties_M-Xylene_wt%           0.999905  ...  0.398676
# Heart Cut Product Properties_O-Xylene_wt%           0.999841  ...  0.526754
# Heart Cut Product Properties_2-Methyloctane_wt%      0.99922  ...  0.526073
# Heart Cut Product Properties_1-Nonene_wt%           0.998549  ...  0.560743
# Heart Cut Product Properties_n-Nonane_wt%           0.999302  ...  0.536425
# Heart Cut Product Properties_i-Propylbenzene_wt%    0.999363  ...  0.523775
# Heart Cut Product Properties_1-trans-3,5-Trimet...  0.999028  ...  0.487926
# Heart Cut Product Properties_n-Propylcyclohexan...  0.997477  ...  0.456126
# Heart Cut Product Properties_n-Propylbenzene_wt%    0.999618  ...  0.460892
# Heart Cut Product Properties_1,3,5-Trimethylben...  0.999628  ...  0.579853
# Heart Cut Product Properties_1-Methyl-2-ethylbe...  0.999629  ...   0.45369
# Heart Cut Product Properties_1,2,3-Trimethylben...  0.999781  ...  0.514354
# Heart Cut Product Properties_2,4-Dimethyloctane...  0.998934  ...  0.518496
# Heart Cut Product Properties_2,2,3,3-Tetramethy...  0.999207  ...  0.547001
# Heart Cut Product Properties_3-Methylnonane_wt%     0.999455  ...  0.575997
# Heart Cut Product Properties_tert-Butylcyclohex...  0.999849  ...  0.488237
# Heart Cut Product Properties_n-Decane_wt%           0.999863  ...       NaN
# Heart Cut Product Properties_1,2-Diethylbenzene...  0.999817  ...  0.516595
# Heart Cut Product Properties_n-Undecane_wt%         0.999832  ...       NaN
# Heart Cut Product Properties_n-Pentylbenzene_wt%    0.999787  ...  0.550238
# Heart Cut Product Properties_n-Dodecane_wt%         0.999862  ...       NaN
# Heart Cut Product Properties_n-Hexylbenzene_wt%      0.99977  ...       NaN
# Heart Cut Product Properties_n-Tridecane_wt%               1  ...       NaN
# Heavy End Product Properties_Oxygen_wt%                    1  ...       NaN
# Heavy End Product Properties_Methane_wt%                   1  ...       NaN
# Heavy End Product Properties_Ethane_wt%                    1  ...       NaN
# Heavy End Product Properties_Propane_wt%                   0  ...       NaN
# Heavy End Product Properties_n-Butane_wt%           0.969396  ...       NaN
# Heavy End Product Properties_i-Pentane_wt%          0.969389  ...   6964.58
# Heavy End Product Properties_n-Pentane_wt%            0.9664  ...   6670.19
# Heavy End Product Properties_tr2-Pentene_wt%        0.973635  ...       NaN
# Heavy End Product Properties_Cyclopentane_wt%       0.851287  ...       NaN
# Heavy End Product Properties_3-Methylpentane_wt%     0.96866  ...   3162.14
# Heavy End Product Properties_tr2-Hexene_wt%         0.969814  ...       NaN
# Heavy End Product Properties_n-Hexane_wt%           0.972373  ...   2907.89
# Heavy End Product Properties_Methylcyclopentane...  0.978121  ...   5613.56
# Heavy End Product Properties_2,2-Dimethylpentan...  0.981242  ...   6741.93
# Heavy End Product Properties_Benzene_wt%            0.983083  ...       NaN
# Heavy End Product Properties_Cyclohexane_wt%        0.984431  ...   6138.92
# Heavy End Product Properties_2,2,3-Trimethylbut...  0.983245  ...   5168.44
# Heavy End Product Properties_4-Methyl-1-hexene_wt%  0.985571  ...   4931.55
# Heavy End Product Properties_2-Methylhexane_wt%     0.987763  ...   4110.08
# Heavy End Product Properties_t-1,3-Dimethylcycl...  0.990687  ...   5503.43
# Heavy End Product Properties_n-Heptane_wt%          0.993649  ...   5756.62
# Heavy End Product Properties_H2O_wt%                       1  ...       NaN
# Heavy End Product Properties_Methylcyclohexane_wt%  0.998327  ...     13524
# Heavy End Product Properties_Ethylcyclopentane_wt%   0.99795  ...   15702.7
# Heavy End Product Properties_2,3-Dimethyl-1-hex...  0.936834  ...   13606.5
# Heavy End Product Properties_Toluene_wt%             0.97458  ...   9877.03
# Heavy End Product Properties_2-Methylheptane_wt%    0.907691  ...   20203.2
# Heavy End Product Properties_n-Octane_wt%            0.89613  ...    1732.3
# Heavy End Product Properties_Ethylcyclohexane_wt%   0.985817  ...   124.878
# Heavy End Product Properties_EthylBenzene_wt%       0.987986  ...   126.353
# Heavy End Product Properties_P-Xylene_wt%            0.99348  ...   144.484
# Heavy End Product Properties_M-Xylene_wt%           0.994109  ...   158.429
# Heavy End Product Properties_O-Xylene_wt%           0.995325  ...   103.751
# Heavy End Product Properties_2-Methyloctane_wt%     0.992645  ...   40.6071
# Heavy End Product Properties_1-Nonene_wt%           0.987978  ...   13.9513
# Heavy End Product Properties_n-Nonane_wt%           0.994334  ...   3.63515
# Heavy End Product Properties_i-Propylbenzene_wt%     0.98911  ...   3.06508
# Heavy End Product Properties_1-trans-3,5-Trimet...  0.993864  ...   48.9912
# Heavy End Product Properties_n-Propylcyclohexan...  0.990153  ...   1.51125
# Heavy End Product Properties_n-Propylbenzene_wt%    0.996174  ...   1.52945
# Heavy End Product Properties_1,3,5-Trimethylben...  0.996188  ...   1.59744
# Heavy End Product Properties_1-Methyl-2-ethylbe...  0.996169  ...   1.51817
# Heavy End Product Properties_1,2,3-Trimethylben...  0.996669  ...   1.56469
# Heavy End Product Properties_2,4-Dimethyloctane...  0.991687  ...   2.35861
# Heavy End Product Properties_2,2,3,3-Tetramethy...  0.992252  ...   1.55114
# Heavy End Product Properties_3-Methylnonane_wt%     0.994941  ...   1.58071
# Heavy End Product Properties_tert-Butylcyclohex...  0.996276  ...   1.56558
# Heavy End Product Properties_n-Decane_wt%           0.998047  ...       NaN
# Heavy End Product Properties_1,2-Diethylbenzene...  0.998575  ...   1.59814
# Heavy End Product Properties_n-Undecane_wt%         0.997918  ...       NaN
# Heavy End Product Properties_n-Pentylbenzene_wt%    0.998588  ...   1.62979
# Heavy End Product Properties_n-Dodecane_wt%         0.998419  ...       NaN
# Heavy End Product Properties_n-Hexylbenzene_wt%       0.9986  ...       NaN
# Heavy End Product Properties_n-Tridecane_wt%               1  ...       NaN
# AVG                                                  0.92148  ...   1228.79
#
# [163 rows x 3 columns]

# %%
import joblib
joblib.dump(part1,'part1.pkl')
# Out:
# ['part1.pkl']

# %%
result.to_csv('result(162wt%)')
